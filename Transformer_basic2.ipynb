# %% [markdown]
# <a href="https://colab.research.google.com/github/Razerx11/ai-660710757/blob/main/Transformer_basic2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 92.2 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 63.7 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁ਸਮਾਂ': 83957,
#  '▁ungase': 217834,
#  'కలు': 239046,
#  '▁เฮ้': 165050,
#  'övet': 154515,
#  '肘': 254296,
#  'ubay': 126650,
#  '▁ବିଶେଷ': 91308,
#  '▁осраҡта': 216659,
#  '高価': 202958,
#  'роти': 219146,
#  '▁ဖျ': 157836,
#  '▁இப்போ': 121674,
#  '▁pirmās': 166804,
#  '▁kombisaka': 95131,
#  '▁Holmes': 143372,
#  '▁प्रति': 9892,
#  '▁सांगतो': 234058,
#  '▁Аны': 65033,
#  'ıllı': 190447,
#  'trasport': 85207,
#  '▁Nay': 31320,
#  'datt': 218440,
#  '▁അറിയ': 37607,
#  '▁družbe': 121876,
#  '▁bangas': 131696,
#  '▁rendelet': 61050,
#  '▁ئاو': 49467,
#  '▁Halu': 58715,
#  '▁منس': 223143,
#  '▁பிள்ளை': 158006,
#  '▁mũsumbĩ': 184914,
#  '▁karna': 89862,
#  '▁دەرکەوت': 170592,
#  '▁pretty': 73090,
#  '▁Патшалык': 158326,
#  'postavljam': 166522,
#  '▁Гол': 162770,
#  'ۆز': 13316,
#  '▁did': 4077,
#  '▁တင်း': 50313,
#  '▁lɛrɛ': 239103,
#  'ိူၵ်ႈ': 115329,
#  'བཀལ་': 71744,
#  'ढ़ी': 99031,
#  'ంధ': 31232,
#  '▁inver': 42063,
#  'ಿದ್ದರು': 36606,
#  '▁достъп': 241407,
#  '▁sítio': 231622,
#  'îd': 135617,
#  '▁basadi': 67630,
#  '▁exercer': 227774,
#  'ijoro': 235510,
#  'лығын': 55224,
#  'र्थिक': 45288,
#  'ชั้น': 88165,
#  'ことはない': 107874,
#  '▁두번째': 151075,
#  '▁നന്ന': 96748,
#  '▁impor': 11791,
#  '▁हूं': 21953,
#  'સિ': 117225,
#  'ătă': 174597,
#  'anyine': 131574,
#  '▁Qan': 139783,
#  '▁నిర్ణయ': 106760,
#  '▁desses': 242470,
#  '▁demokrat': 43076,
#  '▁ইয়': 89455,
#  'iect': 61976,
#  '▁наслідки': 233252,
#  '▁hab': 4976,
#  '▁Nuo': 100000,
#  'म्ब': 61453,
#  '▁ಸಾಧ್ಯವಾದ': 247983,
#  '▁pārs': 95323,
#  '▁অন': 10096,
#  '▁zaintereso': 195009,
#  'લાક': 31003,
#  'জর': 160327,
#  '▁Dawut': 118126,
#  '▁ပရော': 240142,
#  'ったり': 72191,
#  'orge': 74710,
#  'følgende': 161264,
#  'ێز': 27197,
#  'ٻ': 250051,
#  'atada': 226748,
#  '▁paaralan': 184653,
#  'গুলি': 26048,
#  '▁layih': 190705,
#  '▁গান': 107403,
#  '杂': 253679,
#  'Ինչ': 205196,
#  '▁मिलकर': 235059,
#  '窗': 254483,
#  '▁yer': 6545,
#  '▁Папа': 237585,
#  'éla': 108096,
#  '▁पारंपरिक': 181344,
#  '▁šķ': 35185,
#  'under': 20035,
#  '▁doğum': 190063,
#  '▁mínútur': 234737,
#  'unyak': 171798,
#  '▁trước': 13949,
#  'هم': 4571,
#  '▁ensam': 199952,
#  '▁sakit': 17856,
#  '▁વ્યવહાર': 228575,
#  'ത്തോളം': 173141,
#  '▁razmiš': 78600,
#  '▁پارچ': 238430,
#  'jɔ': 60024,
#  'zinisi': 128389,
#  '▁cloud': 113435,
#  '▁über': 9549,
#  '▁mechara': 159035,
#  '▁ningkatkeun': 235632,
#  '▁isleýär': 194465,
#  '▁evil': 100506,
#  '▁암호': 117900,
#  'okwen': 200848,
#  '▁Vag': 240109,
#  'ጠሩ': 128597,
#  '▁betur': 98487,
#  'espi': 101750,
#  'KEE': 114243,
#  '▁ҳастам': 186097,
#  '▁go': 405,
#  'ตื่น': 223613,
#  'fulde': 140249,
#  'quko': 221233,
#  'ുവ': 20167,
#  '▁buu': 63120,
#  '▁Marion': 214425,
#  '▁funkti': 168040,
#  '▁Saboda': 68319,
#  '▁2002.': 63462,
#  '▁swiv': 80278,
#  '꿇': 254881,
#  'ოლ': 12034,
#  'ئف': 82165,
#  '▁götür': 66217,
#  '▁ガ': 138259,
#  '▁Magar': 243570,
#  '▁تېخى': 139675,
#  '▁подаль': 189889,
#  'কৃত': 78129,
#  '▁registri': 244767,
#  '▁desped': 240853,
#  '▁membunuh': 76229,
#  '▁ጽ': 19451,
#  '▁Shikaho': 173741,
#  '▁καλύτερα': 115391,
#  'AP': 18831,
#  '▁vakil': 128692,
#  '▁valódi': 214022,
#  '▁سلی': 144697,
#  '▁במס': 195822,
#  '▁Anyway': 159919,
#  '▁mũĩkĩĩo': 51205,
#  'lada': 22142,
#  '▁تي': 7652,
#  '▁Renault': 169884,
#  '▁tade': 212564,
#  'သည်ဟု': 151780,
#  '▁अशी': 68928,
#  'མངགས་': 210930,
#  'ಲಕ್ಷಣ': 215242,
#  '▁ndin': 51243,
#  'okat': 9374,
#  'lanır': 116692,
#  '▁вәғә': 216879,
#  '▁gheibh': 110406,
#  '▁odprav': 225421,
#  '▁apho': 43702,
#  '್ಟ': 3604,
#  '▁ఖచ్చితంగా': 140069,
#  'qqas': 72652,
#  '▁שבת': 208282,
#  '▁(2008)': 194979,
#  '▁ឬ': 34179,
#  '忿': 255215,
#  '▁44)': 203217,
#  '...]': 6523,
#  '▁گو': 11008,
#  'બે': 77039,
#  '▁रास्ते': 198167,
#  '▁uzņēmējd': 175396,
#  '▁eksportu': 171021,
#  '▁енергије': 205302,
#  '▁mejores': 203181,
#  'บัญ': 233276,
#  '▁사항을': 178888,
#  'гүүд': 219593,
#  'endum': 65793,
#  '▁láithre': 148495,
#  '▁پڌ': 233603,
#  '▁ٹیکنالوجی': 234096,
#  '▁tænke': 146442,
#  '▁Ethĩwa': 100377,
#  '▁cari': 17764,
#  'τσι': 24000,
#  'ின': 10753,
#  '▁cusub': 103717,
#  '▁brein': 212166,
#  '▁විරු': 231244,
#  '▁Mungdan': 207202,
#  'ន្លង': 228932,
#  'はいつ': 245542,
#  '▁sid': 8190,
#  'ুখ': 77429,
#  '▁saus': 143760,
#  '▁lehetőség': 67387,
#  '▁näistä': 176508,
#  '▁kodgi': 144259,
#  '▁Bahan': 203016,
#  '▁koyar': 90932,
#  '許可': 66965,
#  'qankurayku': 228882,
#  '▁נוספים': 200918,
#  '▁মূল্য': 100753,
#  '▁होतं': 64745,
#  '▁määrä': 58266,
#  '▁Izay': 95986,
#  '▁letim': 81376,
#  '▁Erdogan': 117254,
#  '▁araya': 139803,
#  'kolu': 138493,
#  '▁minulla': 113861,
#  '▁తేదీ': 189058,
#  '▁څخه': 28279,
#  '▁forfat': 98148,
#  '▁Uno': 39122,
#  '▁वीडियो': 72819,
#  '▁Tondũ': 221552,
#  '▁እህ': 238730,
#  'Jakobe': 125371,
#  'ティン': 215210,
#  '▁अनुभव': 36913,
#  '▁imir': 66066,
#  '支持': 27023,
#  '▁Empf': 173126,
#  '▁kanyang': 27090,
#  '5:': 109713,
#  '▁Pakist': 163531,
#  '▁trouver': 70203,
#  'šia': 56851,
#  '▁yaabaa': 179582,
#  'ଭାବ': 41935,
#  'ILO': 206988,
#  '▁ҡал': 37032,
#  'vènman': 141328,
#  '▁Pár': 181373,
#  'чард': 206583,
#  'を果た': 177888,
#  '▁muerte': 56486,
#  '▁atrof': 149876,
#  '▁bifu': 215392,
#  'ཞིནམ་': 93464,
#  '▁متف': 44404,
#  '▁bukon': 140765,
#  '▁đói': 201698,
#  '▁engang': 85612,
#  'ནི་སྦེ་': 113323,
#  'kriti': 185843,
#  'nejn': 124127,
#  '▁onk': 132540,
#  '▁prista': 241229,
#  'សោះ': 208918,
#  '▁XVI': 79269,
#  '▁тавь': 142039,
#  'philayo': 192276,
#  'ghe': 40943,
#  '▁gesondheid': 198833,
#  '▁mt': 15183,
#  '▁ietvaros': 118442,
#  'вень': 71301,
#  'ታቸው': 62824,
#  'חורי': 175335,
#  'дко': 179983,
#  '▁Pos': 12013,
#  '▁geçip': 220991,
#  '▁مدیران': 166806,
#  'inye': 8908,
#  'barat': 115284,
#  'स्थ्य': 40050,
#  'ڕە': 171293,
#  '▁hepat': 104752,
#  '▁folosit': 181868,
#  'विरुद्ध': 244007,
#  '▁Même': 131373,
#  '▁документы': 233419,
#  '▁탐험': 200822,
#  '▁ਰੁਪ': 188595,
#  'نداق': 15533,
#  'try': 14388,
#  '▁Господи': 187817,
#  '▁Pho': 67172,
#  '▁చేయ': 10736,
#  'バス': 98568,
#  'ੌਰ': 23512,
#  '▁አመለ': 202737,
#  '▁creat': 115845,
#  '▁câteva': 96069,
#  'тыу': 58920,
#  '▁fwaka': 113291,
#  '▁11:6)': 213413,
#  '몽': 253115,
#  '▁करताना': 162721,
#  '▁menettely': 195005,
#  '▁ၶရိ': 242208,
#  'anuan': 226181,
#  '▁केहि': 119286,
#  'wonongeka': 192727,
#  'angaliso': 138407,
#  '▁hampir': 38929,
#  'fah': 78021,
#  '▁Tiedän': 124824,
#  'ຫາ': 30821,
#  '▁خۆیدا': 187345,
#  'を読': 53587,
#  'ற': 248627,
#  '▁gale': 57587,
#  '▁studerende': 132036,
#  '▁sinifikanti': 104598,
#  '▁וב': 25787,
#  'гура': 158134,
#  '▁مەک': 225674,
#  '▁attivitajiet': 131394,
#  '朵': 254972,
#  '▁chua': 169765,
#  '▁ngun': 75617,
#  'uranye': 138755,
#  'արար': 47408,
#  '▁방황': 238732,
#  'થ્વી': 179238,
#  '▁primjer': 126383,
#  'કારક': 109063,
#  'otwe': 236873,
#  'rega': 34483,
#  'তা': 8802,
#  '▁թափ': 237069,
#  '▁ince': 109494,
#  '犊': 255634,
#  'লী': 111154,
#  '▁کرتا': 24776,
#  '▁කොච්චර': 171348,
#  '▁Cu': 6916,
#  '▁بدل': 46303,
#  '▁սակայն': 103828,
#  '▁hojjet': 168400,
#  '▁novih': 115038,
#  '▁Personen': 111953,
#  '▁випадках': 175397,
#  '▁जनता': 48486,
#  '▁حه': 41397,
#  '▁Valencia': 164486,
#  'стта': 53671,
#  'కుంటున్నాను': 181246,
#  'ങ്ങള്': 31393,
#  'ೋತ್': 161954,
#  '▁يوخ': 31599,
#  '▁Dep': 235996,
#  '▁Morris': 87197,
#  '▁поиска': 167733,
#  '▁enw': 57948,
#  'ishene': 186787,
#  '▁ئىزدە': 117000,
#  'aysa': 134441,
#  '▁syss': 162433,
#  '▁gblɔ': 15539,
#  '▁voldoende': 203662,
#  'ƆL': 227813,
#  'enguva': 78740,
#  '▁wòle': 45550,
#  '▁algorit': 82615,
#  '▁پ': 328,
#  '▁आन्द': 197330,
#  '▁வாச': 213509,
#  '▁Persia': 93655,
#  'asiye': 182115,
#  'ገን': 73929,
#  'anduse': 239973,
#  'nyumba': 87412,
#  '▁содержа': 131186,
#  '▁شهري': 180808,
#  '▁tef': 210912,
#  'ləq': 180586,
#  '▁Xana': 13694,
#  '▁elivulu': 130767,
#  '▁õig': 20331,
#  '▁qhitis': 243821,
#  '▁mega': 51767,
#  'ANO': 126171,
#  '▁baxay': 168379,
#  '▁ashtu': 67870,
#  '▁galimybių': 206198,
#  'sahalo': 160300,
#  'այ': 2126,
#  '▁تێگەی': 243218,
#  '▁Anpil': 185773,
#  '観光': 84112,
#  'xhenxe': 168033,
#  '▁انواع': 82762,
#  '▁Koks': 234829,
#  '▁Nainappa': 60045,
#  '▁dzies': 127126,
#  '▁seiner': 68028,
#  '尝': 253780,
#  '▁pozy': 138626,
#  '▁tshinela': 237989,
#  '▁інстру': 132375,
#  '▁tales': 87854,
#  '▁interesa': 93473,
#  'oració': 196232,
#  '▁sabab': 10196,
#  'ቢድ': 172463,
#  'ɛkɛ': 160560,
#  'پن': 161715,
#  'ያው': 38822,
#  '▁пацієн': 142247,
#  '◎': 254124,
#  '▁politikk': 226851,
#  '▁olemaan': 164168,
#  '▁mabiro': 134662,
#  '▁proble': 36266,
#  '▁zied': 234669,
#  'คนอื่น': 150498,
#  '▁përf': 51938,
#  '〇': 254062,
#  '▁حکمت': 98463,
#  '▁ڕی': 64798,
#  '▁калы': 84424,
#  '▁घायल': 179921,
#  '▁taso': 170641,
#  '▁ممکن': 11432,
#  '▁Lup': 125764,
#  'щі': 67582,
#  '辛': 252622,
#  'ад': 12791,
#  '▁განი': 180911,
#  '▁nụ': 152106,
#  '▁όλοι': 86583,
#  '▁юсти': 169855,
#  '▁makambu': 237809,
#  'кошто': 192556,
#  '▁впро': 163112,
#  'udo': 5631,
#  '▁семейството': 190763,
#  'pezeka': 187538,
#  '▁પ્રાપ્ત': 109900,
#  'bonye': 65003,
#  '▁خوردن': 117819,
#  'čat': 134437,
#  '▁ишенимдүү': 113368,
#  'ávali': 243163,
#  '▁Yaba': 234499,
#  '努力を': 141189,
#  '▁kliyan': 84831,
#  '▁सच': 46462,
#  '▁записа': 160612,
#  'wol_Latn': 256195,
#  'chai': 242374,
#  'বেল': 186350,
#  '는다': 32792,
#  '▁студент': 97133,
#  'ଥ୍ୟ': 146226,
#  '▁당연': 72880,
#  'ätzen': 112977,
#  '하시며': 197981,
#  'дара': 70390,
#  '▁سے': 2261,
#  'ċu': 207731,
#  '▁آگ': 50601,
#  '▁himoya': 108482,
#  'сіб': 53474,
#  '▁Sion': 93886,
#  '▁ھەممىسى': 95265,
#  '▁konċ': 138444,
#  '▁wayo': 49774,
#  '▁dzīvē': 153270,
#  '▁kompensa': 237820,
#  '▁ਪਿ': 50841,
#  'شنبه': 155940,
#  'しないでください': 185119,
#  'ண': 248999,
#  '▁Ehkä': 90005,
#  '▁애플': 109428,
#  'anser': 93670,
#  'ям': 24462,
#  '▁ਕਾਰਵਾਈ': 216509,
#  '▁2022.': 234372,
#  'urà': 181448,
#  '▁qualsiasi': 95183,
#  'bwenge': 149793,
#  '▁pagp': 42588,
#  'ໃນ': 4074,
#  'ğim': 46349,
#  'گرتن': 120885,
#  'митов': 142613,
#  'လား၊': 232413,
#  '▁akapa': 218922,
#  'བྱེད་ཀྱི་': 210188,
#  'ashima': 189733,
#  '▁wuon': 154666,
#  '▁siyos': 170665,
#  '▁moya': 12196,
#  '▁σχολείο': 198936,
#  '▁אָדער': 44520,
#  'espiritu': 88677,
#  'ācijai': 138352,
#  '▁ରୁ': 57309,
#  'कूल': 88117,
#  '▁entit': 194121,
#  'યોગ': 15453,
#  '▁Өм': 133285,
#  '▁sodat': 83376,
#  '▁thabi': 173731,
#  '▁||': 212807,
#  'રાંત': 137990,
#  'ħiħ': 191776,
#  '▁باريش': 178224,
#  '୨': 250603,
#  'Ấ': 252498,
#  'agezi': 85265,
#  '経験': 26374,
#  '▁uPet': 130130,
#  '▁بب': 13348,
#  '欧': 251261,
#  '▁mwambo': 209119,
#  'イスラエル': 36922,
#  'çion': 123282,
#  '▁huono': 192916,
#  'engeri': 132993,
#  'ently': 44833,
#  'མྱ': 38730,
#  'hlangene': 247964,
#  'ngkalingai': 135864,
#  'leɣ': 111021,
#  '▁час': 15003,
#  '대': 248810,
#  '▁mēģ': 125410,
#  'श्मीर': 117061,
#  '▁ଯାଇ': 44010,
#  'gawa': 11533,
#  '▁ndoku': 144445,
#  '▁nwoke': 45424,
#  '▁mantsi': 100641,
#  '▁ਆਪਣੀ': 35278,
#  'ཏོག་': 51364,
#  'wangun': 84010,
#  'фера': 81941,
#  'wavo': 75302,
#  '▁stano': 143485,
#  '▁matumaa': 224188,
#  'zɩ': 5765,
#  '▁Teh': 38400,
#  '▁leher': 201615,
#  'тар': 2245,
#  '▁nesten': 76293,
#  '▁mňa': 67879,
#  'インド': 31092,
#  '▁smua': 165484,
#  'נדי': 190340,
#  'нун': 19666,
#  '▁učinkovitost': 244964,
#  'alty': 102319,
#  '"...': 10183,
#  '▁હિ': 132161,
#  '▁యా': 74645,
#  '▁بازدید': 109016,
#  'ಂಕ': 54139,
#  '▁беҙҙе': 121561,
#  '▁opak': 156441,
#  'ovina': 42842,
#  'ត្តិ': 70497,
#  'emde': 68169,
#  'vám': 174702,
#  'ischer': 93743,
#  'itenga': 132013,
#  '▁memanfaatkan': 154113,
#  'anyãli': 242995,
#  'സിന്റെ': 175277,
#  'undum': 135938,
#  '▁8,000': 204099,
#  '▁satelit': 126157,
#  'aree': 98450,
#  '▁tulev': 183814,
#  '▁lolon': 182532,
#  '▁служ': 28625,
#  'སྒྲིགས་': 204872,
#  'اللہ': 128669,
#  '▁pomočjo': 205557,
#  '▁juh': 16302,
#  '計算': 72690,
#  '▁waktunya': 179206,
#  'ಮೆಯ': 192863,
#  '▁puter': 179462,
#  '▁banag': 76631,
#  '▁whare': 45660,
#  'ସ୍ତ୍ର': 132986,
#  '▁هنگام': 70635,
#  'asser': 176081,
#  '▁মতম': 70471,
#  'གྱི་': 7198,
#  'dyr': 49614,
#  '▁Sh': 4126,
#  '▁schvál': 107187,
#  '夜の': 191772,
#  '▁rafiki': 150100,
#  'Yel': 207100,
#  '▁kompetenti': 49805,
#  '▁nat': 2473,
#  '▁Tɩmote': 170852,
#  '▁耶和華': 102112,
#  '▁ترجیح': 116468,
#  '▁εμάς': 217176,
#  '压': 253366,
#  '▁goes': 65639,
#  '▁etim': 82416,
#  '▁muncă': 184625,
#  'にその': 211031,
#  '▁جيدة': 141556,
#  'andĩki': 115035,
#  '▁kũvoya': 235072,
#  'ighe': 21466,
#  '▁معيار': 150712,
#  'ರ': 248346,
#  'Job': 97842,
#  '▁освобо': 111316,
#  'uaño': 92678,
#  '▁fanau': 65508,
#  'து': 1450,
#  '▁investor': 71410,
#  'enem': 49047,
#  '▁maran': 52658,
#  '▁müşter': 148014,
#  '▁algas': 211892,
#  'ナ': 249672,
#  'ముగా': 146108,
#  'jenosti': 231633,
#  '▁Egypt': 59365,
#  '▁grat': 123584,
#  'litso': 215504,
#  'ik': 66,
#  '▁קודם': 125463,
#  'stand': 9773,
#  '▁mukenji': 221885,
#  '▁ક્ર': 68066,
#  '▁berer': 154208,
#  'struct': 214110,
#  'אות': 27499,
#  '▁ஆரம்ப': 185586,
#  'ᱫ': 250504,
#  '▁kompens': 73240,
#  'ILI': 144573,
#  '▁મોડે': 243363,
#  '▁poskytuje': 145600,
#  '▁જરૂરિયા': 127326,
#  '▁piu': 21696,
#  '▁mañá': 185439,
#  '▁abɛ': 111691,
#  'ものを': 26833,
#  'ónu': 78526,
#  'Sc': 239575,
#  '▁દો': 64420,
#  'חים': 35720,
#  'ιος': 28621,
#  '▁тұлғаның': 206087,
#  'へ行': 178962,
#  'өөлөр': 114775,
#  '▁Kɔc': 92474,
#  '▁ievēr': 247903,
#  '기': 248618,
#  '▁maqs': 41635,
#  '▁nonofo': 100613,
#  '▁nyua': 185347,
#  '▁құр': 143175,
#  '▁litta': 82723,
#  '▁그러고': 219326,
#  '▁Milo': 225689,
#  '▁폭풍': 204802,
#  '▁сол': 26155,
#  'jir': 27829,
#  '▁රි': 88600,
#  '▁super': 8095,
#  '▁Australian': 139958,
#  '▁Muana': 224130,
#  '▁עדיין': 52648,
#  'xxam': 114184,
#  '▁فہرست': 216770,
#  '▁тре': 6924,
#  '▁tanggungjawab': 197853,
#  '▁Ғайса': 42146,
#  '▁dobil': 182735,
#  'ɔŋlɔ': 77513,
#  'idih': 211702,
#  'łaś': 23432,
#  'して下さい': 183613,
#  '▁মাঝে': 90044,
#  '▁kringum': 227003,
#  '림픽': 189592,
#  '▁volonté': 172453,
#  '▁muz': 30032,
#  '▁iwa': 47942,
#  'тері': 24932,
#  '住んでいる': 228982,
#  '▁subs': 35320,
#  '▁członko': 78964,
#  'ātiem': 116047,
#  'veau': 18877,
#  '▁سۭتۍ': 96837,
#  'jama': 22288,
#  '▁dæ': 68991,
#  '▁몰라': 126220,
#  'uriro': 134452,
#  '▁해결할': 185951,
#  '▁माग': 65917,
#  '▁നാല': 137090,
#  'ہیز': 162028,
#  '▁کھلا': 149790,
#  '▁Política': 149967,
#  '▁секто': 101401,
#  '▁Hector': 225413,
#  '▁laikotarpį': 152638,
#  '▁শাস্তি': 174479,
#  '▁oṣu': 170450,
#  '▁épület': 181984,
#  '▁кажем': 163683,
#  '▁Ճ': 143734,
#  'న్ని': 6300,
#  '▁इंज': 101219,
#  'дишь': 175334,
#  '▁народу': 104206,
#  'ਦਾਰ': 53483,
#  '▁XXI': 126046,
#  '▁годин': 141337,
#  '▁காலம்': 163751,
#  '抗議': 78415,
#  '▁सक्ती': 206655,
#  'チームは': 108917,
#  '▁మె': 38672,
#  'лыгы': 25888,
#  '7/': 29428,
#  'ებებს': 217616,
#  '▁mistet': 157930,
#  'wetso': 101649,
#  '▁گەی': 108961,
#  'feagai': 92409,
#  '▁luns': 178388,
#  '▁වූයේ': 209339,
#  '▁ameneŵa': 191655,
#  '▁희생': 75342,
#  '感谢': 188471,
#  '▁нощ': 126653,
#  '▁operatori': 152824,
#  '▁vevietɔ': 226674,
#  'GLWYDD': 89723,
#  '▁ຊ່ວຍ': 147283,
#  '▁Mf': 185409,
#  '剩': 253480,
#  '▁یاخود': 83993,
#  '▁ଶବ୍': 184325,
#  'irur': 236179,
#  '▁지도': 42464,
#  'ଥିଲ': 4682,
#  '▁nữ': 33602,
#  '▁sommige': 85527,
#  'ች።': 106321,
#  'וא': 2756,
#  '▁নোহ': 244462,
#  '▁حفاظت': 70946,
#  'оз': 80446,
#  '▁بىلىم': 219218,
#  '▁هٿ': 104341,
#  '▁Angli': 166710,
#  'ombiali': 210834,
#  'anter': 103172,
#  'μαν': 76872,
#  '▁현실': 50401,
#  '▁kimvuka': 129747,
#  '▁мәсихче': 61433,
#  '▁eksporto': 223709,
#  '▁ചിക': 204321,
#  '▁дуже': 29354,
#  '▁пациен': 154694,
#  '▁hankal': 149805,
#  'fatša': 86018,
#  '基礎': 95556,
#  'ტატ': 177613,
#  'ветно': 227686,
#  '▁Claudia': 221878,
#  '磁': 252876,
#  '▁танҳо': 59586,
#  '▁rā': 32019,
#  '▁ကိုယ္': 120520,
#  'ളിൽ': 187493,
#  'бено': 63816,
#  '▁zmluv': 143488,
#  '▁እግ': 178179,
#  '▁mnoho': 100681,
#  'റേ': 173942,
#  'odama': 221667,
#  'ፈረ': 217735,
#  'asipxam': 158306,
#  '▁محفوظ': 68013,
#  '▁esmės': 169245,
#  'umbane': 176943,
#  '▁ئىنت': 168619,
#  '腊': 254157,
#  'लेली': 123844,
#  '▁dyond': 13956,
#  '분에': 104509,
#  '▁당장': 134196,
#  'ፈልግ': 76208,
#  '▁сказал': 43318,
#  'ホール': 199335,
#  '▁مطالعات': 76825,
#  '▁ചെയ്യും': 88114,
#  '플레이': 211034,
#  '▁àtàwọn': 68772,
#  '纠': 255866,
#  '▁hanyo': 57719,
#  'ಪಟ್ಟ': 146367,
#  'tajiet': 144254,
#  '▁nesp': 98695,
#  '▁paragraph': 78384,
#  '▁Wena': 78264,
#  '▁መግለጫ': 223329,
#  'kulela': 150497,
#  '▁gospodar': 68212,
#  'årene': 238762,
#  '▁vakadonui': 203785,
#  '▁tervise': 217375,
#  '▁заве': 127265,
#  '▁chimwe': 64535,
#  '▁mikenji': 144165,
#  '▁утвр': 110774,
#  'ongozgi': 118096,
#  '▁손실': 99529,
#  'سبة': 95487,
#  '単純な': 197178,
#  '▁nonyiso': 140899,
#  '▁جاھان': 239503,
#  '▁почати': 247746,
#  '▁poważ': 172875,
#  'Matayo': 61169,
#  '▁ওদের': 130362,
#  '▁muchas': 97457,
#  '▁популяр': 117362,
#  '▁Akhristu': 135249,
#  '▁हजारों': 235403,
#  '▁Lær': 168018,
#  '▁Kah': 26484,
#  '▁riż': 73114,
#  'ಿಕಿ': 76595,
#  'ליך': 65473,
#  '▁nepie': 27728,
#  '▁سرگر': 90420,
#  '▁نورو': 94068,
#  'erik': 65960,
#  'ⵇⵇ': 100736,
#  'ং': 249045,
#  '▁criteri': 85337,
#  '▁respostas': 241634,
#  '▁iddo': 38085,
#  '▁anochi': 200554,
#  '▁Pamrentahan': 140791,
#  '▁dibut': 192028,
#  '▁વાત': 33265,
#  '▁buru': 23025,
#  'agħ': 89781,
#  '▁nagħmlu': 177677,
#  '▁spéci': 120479,
#  'ulanda': 191049,
#  '▁کەسان': 117002,
#  'ōd': 205187,
#  '▁међу': 37760,
#  '▁ізде': 145999,
#  'മായിരിക്കും': 238706,
#  'kipun': 33644,
#  '▁5:11)': 228032,
#  '▁unicamente': 238351,
#  '▁Singapur': 240719,
#  '▁ਅਤੇ': 4504,
#  '▁ҡыл': 211187,
#  '▁add': 10976,
#  '自己嘅': 187197,
#  'škega': 98379,
#  'దు': 5819,
#  '▁domeni': 227896,
#  '▁Башҡортостан': 40718,
#  '▁thur': 185350,
#  'োৱাত': 153034,
#  '▁쉽고': 233946,
#  '▁garga': 27136,
#  'paragrafi': 142367,
#  '▁kunazo': 217517,
#  '▁nunna': 185578,
#  'ཞུཝ་': 130535,
#  '▁ಇತ್ತೀಚ': 163138,
#  '▁স্ত্রী': 143501,
#  '▁xəbər': 80086,
#  '▁ише': 31878,
#  'gbà': 8680,
#  '▁Ngaloo': 184170,
#  '▁åtgär': 165086,
#  '▁oprind': 182246,
#  'عات': 17631,
#  '▁góðu': 244127,
#  '▁ŵabali': 120910,
#  '▁започ': 121873,
#  '▁Jeruthalem': 122472,
#  '▁tshamaka': 103156,
#  'wendo': 131203,
#  '▁vytvoriť': 169625,
#  'ودۆ': 181261,
#  '▁পব': 135010,
#  '▁સ્થાપ': 104363,
#  '▁potravin': 196023,
#  'మని': 45158,
#  'celler': 203012,
#  '▁инспи': 177387,
#  'பம்': 181617,
#  '▁моль': 223322,
#  '▁उहे': 200499,
#  '▁ሁለቱ': 221662,
#  '▁manajer': 141348,
#  '▁nepod': 234213,
#  '▁yekka': 165174,
#  'وی': 2805,
#  '▁31': 5493,
#  '▁âmbito': 123232,
#  '▁ọchịchị': 89181,
#  '▁ambanin': 237968,
#  'jellen': 234366,
#  'மையான': 74022,
#  '▁való': 26417,
#  '▁ukudla': 98315,
#  'immoo': 214503,
#  '▁kusuhi': 135756,
#  '▁Tind': 129944,
#  '▁Рад': 178692,
#  '▁دوروب': 242268,
#  'まず': 51317,
#  'кунанда': 153686,
#  'sin_Sinh': 256153,
#  '▁duygu': 236050,
#  '▁ٱب': 33963,
#  '▁zab': 21410,
#  '▁Dest': 109332,
#  '▁ਬਰ': 118039,
#  'țț': 147607,
#  'qondo': 31335,
#  '▁ов': 44844,
#  '▁Шу': 11655,
#  '▁невели': 173260,
#  'མ་བྱེད་': 241033,
#  '▁16,': 29192,
#  '▁awer': 45156,
#  '▁kiba': 59505,
#  '▁pekerjaan': 37414,
#  '▁меку': 15004,
#  'ენი': 56150,
#  'daidh': 199586,
#  'wongereza': 198180,
#  '▁amt': 75240,
#  'грани': 38156,
#  '▁Пу': 43470,
#  'hones': 228322,
#  'ುತ್ತಾನೆ': 103880,
#  'ūst': 51048,
#  '▁vake': 44807,
#  '▁cul': 13737,
#  '២': 251131,
#  'oleni': 111172,
#  '▁ఉపయోగ': 187912,
#  '▁ovisi': 230812,
#  '蛇': 253573,
#  'arakim': 235866,
#  '▁controver': 229884,
#  '▁control': 14117,
#  'باما': 161816,
#  'իրոջ': 142024,
#  '▁gumi': 49055,
#  '▁berildi': 179662,
#  'itaja': 220037,
#  '▁በሁሉም': 216465,
#  '▁picha': 104984,
#  '▁точно': 44858,
#  '▁Zotit': 92854,
#  '▁zawh': 90435,
#  '▁astea': 87734,
#  '▁rota': 85815,
#  'ုၼ်': 123964,
#  '▁mabbir': 229990,
#  '▁ხართ': 101619,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# ผู้ชาย
# ▁ฉันต้อง
# มีอะไร
# เน
# คืน
# าว
# ข่าว
# ิง
# แก
# หนู
# ▁แต่ผม
# เปล่า
# ▁โลก
# เตียน
# รักษา
# เขียน
# เกี่ย
# พวกนั้น
# ยะ
# เรีย

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04627328, -0.00378876],
#        [-0.02224129,  0.02343198],
#        [-0.03137536,  0.01103146],
#        [ 0.04373031,  0.04959117]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a2acc0d9-841f-4905-b403-c36a1fdc0bfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2acc0d9-841f-4905-b403-c36a1fdc0bfc")) {                    Plotly.newPlot(                        "a2acc0d9-841f-4905-b403-c36a1fdc0bfc",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[-0.031569995,-0.049307417,0.042139445,0.015285108,0.010625899,-0.0055847988,0.037905578,-0.01007881,0.008133542,-0.032696594,-0.023281742,-0.01885339,0.0120976195,0.044167053,0.01133424,-0.011418521,-0.0153996125,0.020028438,-0.04062009,-0.013085365,0.043279443,0.020099644,-0.0042750947,0.046523463,0.0463931,0.036056068,0.02090006,0.016391668,-0.00772468,-0.04343418,0.029037442,0.019559983,0.019205395,0.04010311,0.0025555007,-0.024220182,0.023472462,-0.02950865,-0.022832228,-0.030925358,0.031909022,0.020739999,-0.046381153,0.008628678,-0.027636994,0.008469343,-0.047608532,-0.014652122,-0.03974998,0.032734405,-0.022381617,0.026818369,0.019260716,-0.014005113,0.012340713,0.04325011,-0.041922342,0.04707623,0.034459803,0.0039930455,0.004142415,-0.006290294,-0.022689307,-0.009786438,0.01410884,0.049678933,-0.016558312,-0.011343598,0.03971037,-0.045057632,-0.010228813,0.012284875,-0.038600683,0.039372448,0.0071172826,-0.047194637,0.03127945,0.043638375,0.028513078,-0.03516517,0.046318594,0.040443484,0.010716222,-0.032851472,0.041114215,0.019985747,0.021980476,0.045497466,0.001070559,0.013853993,0.014624868,0.03318168,0.0043875687,-0.04283768,0.0013076551,0.023897793,0.017661642,-0.029818464,0.00059442595,0.005119942,0.017510448,-0.003028132,-0.0009205453,0.015129458,0.026859988,0.009501766,0.03215948,0.030501615,0.005207859,0.034624446,0.03744838,0.030136239,-0.014848731,0.005188465,-0.017131437,0.0057699084,-0.035814963,-0.047251355,0.03455038,-0.035329998,0.04206605,-0.014644254,0.027443293,-0.000059463084,-0.044864144,-0.015568424,0.032969918,-0.023571182,-0.0001456514,0.041088033,0.001806628,0.043686178,0.0012202747,-0.037406527,-0.021591557,-0.013096523,0.02944478,0.041092087,-0.032303143,-0.0030934922,0.012785684,0.03512169,0.043660972,-0.035439122,0.03361967,-0.032786444,-0.025090778,-0.006339945,0.029649545,0.028121714,-0.04890425,-0.03927598,0.0063481107,-0.000057518482,-0.038461994,0.007451486,-0.017668642,0.042917002,-0.042685818,0.018377569,-0.039339136,-0.010412335,-0.009571254,-0.0054987893,-0.020509839,-0.026671028,-0.0049797893,0.015631747,0.0010951646,0.044824194,0.009702839,-0.0050698146,-0.014991783,0.025965702,0.023683812,0.032479707,-0.04393008,-0.040634014,-0.023029912,0.021895755,0.04132383,0.015481625,0.003990721,-0.032792427,-0.0066223517,-0.02031423,0.028145757,-0.037770174,0.029841673,0.04757135,0.013153683,-0.039889835,0.028403472,-0.04355395,-0.045826223,0.010045756,-0.044786345,0.00829611,0.011893846,0.006964814,0.01572213,0.015070666,-0.028734744,-0.048464477,-0.020738114,0.0011704564,0.01683012,0.0034247153,-0.046259284,-0.02605716,0.010531448,-0.04815135,0.040816035,-0.046046104,0.016553406,0.021202479,-0.0011745468,0.030937482,0.039846603,-0.04093518,0.046882,-0.008872367,-0.0353253,-0.030118097,0.030453827,0.024575043,0.00054911524,-0.035784077,0.017889831,-0.04564644,0.005127061,0.016006853,-0.03339257,0.026368607,-0.020835256,-0.0022319928,0.006253112,0.038666848,0.037051227,-0.038068198,0.012932431,0.026553024,-0.043022882,0.049583245,0.02641305,-0.038156234,0.02659278,0.033919048,0.018396888,0.04258803,0.038816098,-0.035120763,0.039347176,0.02300812,-0.0038908832,0.0043031797,-0.012344241,-0.035669766,0.04404844,0.014013555,-0.003937982,0.046833668,-0.007170655,-0.018451571,0.015340578,0.04255564,0.019750778,0.018723238,-0.018003903,-0.041049898,0.008080315,-0.011369955,- ...
# Default initializer range  -0.04999881 0.04999974
# Glorot initializer range  -0.0109542 0.0109537495

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0d7346c5-4c8e-46d8-8187-18a0471841c4" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d7346c5-4c8e-46d8-8187-18a0471841c4")) {                    Plotly.newPlot(                        "0d7346c5-4c8e-46d8-8187-18a0471841c4",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04627328, -0.00378876],
#        [-0.02224129,  0.02343198],
#        [-0.03137536,  0.01103146],
#        [ 0.04373031,  0.04959117]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 4.7034924e-03,  2.4433723e-02],
#        [ 4.2076958e-03,  5.9434213e-05],
#        [-6.5623666e-04, -1.1945076e-02],
#        [ 2.0360012e-02,  5.2132472e-02]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.03824433,  0.00312146],
#        [-0.00170132,  0.01330471],
#        [-0.0193994 ,  0.00368094],
#        [ 0.07718433,  0.03937642]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.01921831,  0.02568356,  0.01425983,  0.02934961],
#        [ 0.01037479, -0.00422827,  0.00801943, -0.00862119],
#        [-0.00535108, -0.01423629, -0.00384459, -0.01775223],
#        [ 0.06641594,  0.04424217,  0.05007093,  0.04123382]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 2.5615087e-04  3.1708152e-04 -1.3057652e-06  1.3251484e-03]
#  [ 1.6110601e-04 -6.3678804e-06 -8.1407998e-05  3.2710849e-04]
#  [-6.2383449e-05 -1.5780935e-04 -3.1238556e-05 -5.2100554e-04]
#  [ 9.4138458e-04  6.5896870e-04 -2.0307528e-04  3.6242639e-03]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.24996144 0.2499722  0.24991594 0.25015044]
#  [0.2500108  0.24998118 0.24996792 0.2500401 ]
#  [0.2500231  0.25000626 0.2500286  0.24994206]
#  [0.24994437 0.24989446 0.24974218 0.250419  ]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.0226739  0.01287227 0.01713348 0.01105931]
#  [0.02266734 0.01286788 0.01712853 0.01105521]
#  [0.022661   0.01286289 0.01712377 0.01105023]
#  [0.02269153 0.01288652 0.01714673 0.01107363]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.0226739  0.01287227 0.01713348 0.01105931]
#  [0.02266734 0.01286788 0.01712853 0.01105521]
#  [0.022661   0.01286289 0.01712377 0.01105023]
#  [0.02269153 0.01288652 0.01714673 0.01107363]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.01621626]
#  [0.01621126]
#  [0.0162061 ]
#  [0.01623079]]

# %%
tf.random.set_seed(123)

block_size = embedded_sentence.shape[0]   # [T, d_in] → T = sequence length

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.01621626 0.02066624 0.02517765]
#  [0.01621126 0.02064543 0.02513368]
#  [0.0162061  0.02063652 0.02512572]
#  [0.01623079 0.02068552 0.02518289]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
